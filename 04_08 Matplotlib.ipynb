# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
data = np.arange(10)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">

# %%
plt.scatter(data,data)

# %%
fig = plt.figure()  # figure behaves like a canvas
                    # if we do not close figure , all the plots will be created on existing figure
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">

# %%
fig = plt.figure(figsize=(5,5))
# Out:
# <img src="data:image/png;base64,..." width="570.8042286371783">

# %%
p1 = fig.add_subplot(2,2,1)
p2 = fig.add_subplot(2,2,2)
p3 = fig.add_subplot(2,2,3)
p4 = fig.add_subplot(2,2,4)

# %%
p1 = fig.add_subplot(3,2,1)
p2 = fig.add_subplot(3,2,2)
p3 = fig.add_subplot(3,2,3)
p4 = fig.add_subplot(3,2,4)
p5 = fig.add_subplot(3,2,5)
p6 = fig.add_subplot(3,2,6)

# %%
p1.plot(np.arange(10),'k-')    # - : single line   ,   -- : dashed line

# %%
p2.scatter(np.arange(30), np.arange(30) + np.random.randn(30) )

# %%
p3.plot(np.arange(10),'m--')

# %%
p4.plot(np.arange(10),'co-')

# %%
fig , axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">

# %%
axes[0].plot(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
axes[1].scatter(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
plt.figure()
x = np.arange(10)
y = np.arange(10)*2
plt.plot(x,y,'r-*')
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">

# %%
plt.figure(figsize=(5,5))
plt.plot(np.random.randn(30) , 'mo--' , label = 'FirstPlot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple line plot')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="570.8042286371783">

# %%
plt.figure()
x = np.arange(10)
y = x**2
z = x**3
plt.plot(x,y,'mo-', label='Squares')
plt.plot(x,z,'bo-', label='Cubes')
plt.title('Squares and Cubes')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="731.6433987278992">

# %%
plt.figure()
x = np.arange(10)
y = x**2
plt.scatter(x,y, s= 100 , c='g')   # s is size of dots , c is color
# Out:
# <img src="data:image/png;base64,..." width="731.6433987278992">

# %%
plt.xticks(np.arange(10))
# Out:
# ([<matplotlib.axis.XTick at 0x2a6b724f0a0>,
# ...
#  [Text(-2.0, 0, '−2'),
#   Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.yticks(np.arange(0,100,5))
# Out:
# ([<matplotlib.axis.YTick at 0x2a6b72a3a00>,
# ...
#  [Text(0, -10.0, '−10'),
#   Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60'),
#   Text(0, 70.0, '70'),
#   Text(0, 80.0, '80'),
#   Text(0, 90.0, '90'),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Bar Graph

# %%
plt.figure()
x = np.arange(10)
y = x*2
plt.bar(x,y, width=0.8)
plt.xticks(x)
plt.yticks(y)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# ([<matplotlib.axis.YTick at 0x2a6b5503580>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.arange(10)
y = x*2
z = x*4
plt.bar(x,y, width=0.4 , color = 'm')
plt.bar(x,z, width=0.4 , color = 'c' , bottom=x)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# <BarContainer object of 10 artists>

# %%
plt.figure()
x = np.arange(10)
y = x*2
z = x*4
plt.bar(x-0.2,y, width=0.4 , color = 'm')
plt.bar(x+0.2,z, width=0.4 , color = 'c')
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Histogram

# %%
plt.figure()
plt.hist([1,2,3,4,5,4,2,3,4,5,8,9] , width = 0.6)
plt.xticks(range(10))
plt.yticks(range(5))
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# ([<matplotlib.axis.YTick at 0x2a6b9df2850>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.random.normal(100,10,500)
plt.hist(x)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# (array([  5.,   7.,  29.,  71.,  97., 126.,  96.,  55.,  11.,   3.]),
#  array([ 67.36457817,  73.4896278 ,  79.61467742,  85.73972705,
#          91.86477668,  97.9898263 , 104.11487593, 110.23992556,
#         116.36497519, 122.49002481, 128.61507444]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure()
x = np.array([10,30,20,15,25])
plt.pie(x)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# ([<matplotlib.patches.Wedge at 0x2a6b70c8640>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(-5.149471629032507e-08, 1.0999999999999988, ''),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, ''),
#   Text(-0.49938943041996464, -0.9801072373902886, ''),
#   Text(0.7778175685419842, -0.777817350068405, '')])

# %%
plt.figure()
x = [30,20,40,30,10]
food = ['Bananas', 'Small Bananas' , 'Big Bananas' , 'Tiny Bananas' , 'Extra Large Bananas']
plt.pie(x, labels=food)
# Out:
# <img src="data:image/png;base64,..." width="639.8601766652596">
# ([<matplotlib.patches.Wedge at 0x2a6bdb6f3a0>,
# ...
#  [Text(0.8233618203614949, 0.7294349270298247, 'Bananas'),
#   Text(-0.3900654016728485, 1.0285178571214986, 'Small Bananas'),
#   Text(-1.0680359783135132, -0.2632473153289448, 'Big Bananas'),
#   Text(0.3900654979696379, -1.0285178206009358, 'Tiny Bananas'),
#   Text(1.0680360337692223, -0.2632470903362633, 'Extra Large Bananas')])

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(X_train , Y_train) , (X_test,Y_test) = mnist.load_data()

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
plt.figure()
plt.imshow(X_train[0])

# %%
plt.figure(figsize = (10,10))
for i in range(100):
    plt.subplot(10,10,1+i)
    plt.axis('off')
    plt.imshow(X_train[i] , cmap='gray')
