# %% [raw]
# distplot : It is used basically for univariant set of observations and visualizes it through a histogram
#            i.e. only one observation and hence we choose one particular column of the dataset.
#
# lineplot : Draw a line plot with the possibility of several semantic groupings. The relationship between
#            x and y can be shown for different subsets of the data using the hue, size, and style parameters.
#
# scatterplot : Seaborn is an amazing visualization library for statistical graphics plotting . Different markers can be used.
#
# relplot : Relational plots are used for visualizing the statistical relationship between the data points.
#
# barplot :  A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle
#            and provides some indication of the uncertainty around that estimate using error bars.
#
# countplot : Used to Show the counts of observations in each categorical bin using bars.
#
# heatmap : Plot rectangular data as a color-encoded matrix.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
plt.figure()
num = np.random.randn(150)
sns.distplot(num , color='green')
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure()
num = np.random.randn(150)
sns.distplot(num , color='green' , vertical=True)
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density'>

# %%
plt.figure()
num = np.random.randn(150)
sns.distplot(num , color='green', hist=False)
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
col1 = np.linspace(0,10,1000)   # linspace(start,end, num of divisions)
col2 = np.sin(col1)
df = pd.DataFrame({'C1':col1 , 'C2':col2})
df.head()
# Out:
#         C1        C2
# 0  0.00000  0.000000
# 1  0.01001  0.010010
# 2  0.02002  0.020019
# 3  0.03003  0.030026
# 4  0.04004  0.040029

# %%
plt.figure(figsize=(10,6))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x=df.C1 , y=df.C2)
# Out:
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %%
plt.figure(figsize=(12,8))
sns.set(rc = {'axes.facecolor': 'cyan', 'axes.grid': True, 'xtick.labelsize':16, 'ytick.labelsize':16})
sns.lineplot(df.C1, df.C2, data = df, linewidth = 5)
sns.lineplot(df.C1, df.C2+1, data = df, linewidth = 5)
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %%
plt.figure(figsize=(12,8))
sns.set(rc = {'axes.facecolor': '#00bfff', 'axes.grid': True, 'xtick.labelsize':16, 'ytick.labelsize':16})
sns.lineplot(df.C1, df.C2, data = df, linewidth = 5, color = '#ff3385')
sns.lineplot(df.C1, df.C2+1, data = df, linewidth = 5, color = '#ffa31a')
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %%
plt.figure(figsize=(12,8))
sns.set(rc = {'axes.facecolor' : '#283747', 'axes.grid' : False, 'xtick.labelsize' : 16, 'ytick.labelsize':16})
sns.lineplot(x = df.C1, y = df.C2, data = df, linewidth = 3.0, color = '#FF5722')
sns.lineplot(x = df.C1, y = df.C2 + 1, data = df, linewidth = 3.0, color = '#FFEB3B')
# Out:
# <AxesSubplot:xlabel='C1', ylabel='C2'>

# %%
mpl.rcParams.update(mpl.rcParamsDefault)  # to recover default style
# %matplotlib inline

# %%
plt.figure(figsize=(12,8))
sns.set(rc = {'axes.facecolor' : 'white', 'axes.grid' : False, 'xtick.labelsize' : 16, 'ytick.labelsize':16})
sns.lineplot(x = df.C1, y = df.C2, data = df, linewidth = 3.0, color = '#FF5722', label = 'SinWave')
sns.lineplot(x = df.C1, y = df.C2 + 1, data = df, linewidth = 3.0, color = '#FFEB3B', label = 'SinWave + 1')
plt.title('Cool stuff with seaborn')
# Out:
# Text(0.5, 1.0, 'Cool stuff with seaborn')

# %%
auto = pd.read_csv('D:\College\REG EX\Dataset\Automobile_data.csv')
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='wheel-base' , y='engine-size' , data=auto)
# Out:
# <AxesSubplot:xlabel='wheel-base', ylabel='engine-size'>

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='wheel-base' , y='engine-size' , data=auto , linewidth=5 , color='m')
plt.title('wheelbase vs engine size')
# Out:
# Text(0.5, 1.0, 'wheelbase vs engine size')

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=auto['wheel-base'] , linewidth = 2 , label='Wheel Base')
sns.lineplot(data=auto['engine-size'] , linewidth = 2 , label='Engine Size')
# Out:
# <AxesSubplot:ylabel='wheel-base'>

# %%
plt.figure(figsize = (14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x = 'wheel-base', y = 'engine-size',hue = 'fuel-type', markers = True, data = auto, linewidth = 3)

# hue : This parameter take column name for colour encoding.
# Out:
# <AxesSubplot:xlabel='wheel-base', ylabel='engine-size'>

# %%
plt.figure(figsize = (14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x = 'wheel-base', y = 'engine-size',hue = 'body-style', markers = True, data = auto, linewidth = 3)
# Out:
# <AxesSubplot:xlabel='wheel-base', ylabel='engine-size'>

# %%
plt.figure(figsize = (14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x = 'wheel-base', y = 'engine-size',hue = 'body-style',style='fuel-type' ,markers = True, data = auto, linewidth = 3)

# style :Grouping variable that will produce points with different markers
# Out:
# <AxesSubplot:xlabel='wheel-base', ylabel='engine-size'>

# %%
plt.figure(figsize = (14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x = 'wheel-base', y = 'engine-size',hue = 'body-style',style='fuel-type' ,markers = False, data = auto, linewidth = 3)

# style :Grouping variable that will produce points with different markers
# Out:
# <AxesSubplot:xlabel='wheel-base', ylabel='engine-size'>

# %%
plt.figure(figsize = (14,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x = 'wheel-base', y = 'engine-size',hue = 'fuel-type',style='fuel-type' ,markers = True, data = auto, linewidth = 3)
# Out:
# <AxesSubplot:xlabel='wheel-base', ylabel='engine-size'>

# %%
plt.figure(figsize=(14,7))
sns.set(rc={'xtick.labelsize':17,'ytick.labelsize':10,'axes.labelsize':15 , "axes.grid":False})
# Use "Pallete" to specify the colors to be used for different levels of the hue
sns.lineplot(x="wheel-base" , y="engine-size" , hue = "fuel-type" ,style="fuel-type" , dashes = False,palette = 'CMRmap',markers=["o", ">"] ,data=auto)
plt.show()

# palette : Method for choosing the colors to use when mapping the hue semantic
# dashes : Setting to True will use default dash codes,Setting to False will use solid lines for all subsets.

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='engine-size' , y='wheel-base' , data=auto , color='g')
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='wheel-base'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='engine-size' , y='wheel-base' , data=auto , color='g' , marker='>')
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='wheel-base'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='engine-size' , y='wheel-base' , data=auto , hue='body-style',color='g' )
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='wheel-base'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='engine-size' , y='wheel-base' , data=auto , hue='body-style',style='engine-type',color='g' )
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='wheel-base'>

# %%
plt.figure(figsize=(10,8))
sns.relplot(x='engine-size' , y='wheel-base' , data=auto , hue='body-style',height=8, aspect=2 )

# height : Height (in inches) of each facet. See also: aspect.
# aspect : Aspect ratio of each facet, so that aspect * height gives the width of each facet in inches.

# %%
plt.figure(figsize=(10,8))
sns.relplot(x='engine-size' , y='wheel-base' , data=auto ,kind='line', hue='body-style',height=8, aspect=1.5 )

# %%
plt.figure(figsize=(14,16))
sns.set(rc={'xtick.labelsize':12,'ytick.labelsize':12,'axes.labelsize':12})
sns.relplot(x="wheel-base" , y="engine-size" , hue="fuel-type" ,kind='scatter',palette=["#FF3333" ,"#00CC00"], height=8.5,aspect =1,data=auto)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.relplot(x="wheel-base" , y="engine-size" , hue="engine-location" ,kind='line',palette=["#FF3333" ,"#00CC00"],data=auto ,
            col='body-style')

# %%
plt.figure(figsize=(14,20))
sns.relplot(x="wheel-base" , y="engine-size" , hue="drive-wheels" ,kind='line',data=auto ,col='body-style',col_wrap=3)

# %%
plt.figure(figsize=(14,20))
sns.relplot(x="wheel-base" , y="engine-size" , hue="drive-wheels" ,kind='line',data=auto ,col='num-of-cylinders',col_wrap=3)

# %%
# plt.figure(figsize=(14,20))
sns.relplot(x="wheel-base" , y="engine-size" , hue="drive-wheels" ,kind='line',data=auto ,col='num-of-doors',row='body-style')

# %%
plt.figure(figsize=(9,6))
sns.barplot(auto['body-style'], auto['city-mpg'])
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='city-mpg'>

# %%
plt.figure(figsize=(9,6))
sns.barplot(auto['num-of-cylinders'], auto['city-mpg'])
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num-of-cylinders', ylabel='city-mpg'>

# %%
auto.groupby(['body-style']).mean()['city-mpg']
# Out:
# body-style
# convertible    20.500000
# hardtop        21.625000
# hatchback      26.314286
# sedan          25.322917
# wagon          24.040000
# Name: city-mpg, dtype: float64

# %%
o = auto.groupby(['body-style']).mean().sort_values('city-mpg' , ascending=False)
o
# Out:
#              symboling  wheel-base      length      width     height  \
# body-style
# hatchback     1.585714   95.535714  166.592857  65.247143  52.108571
# sedan         0.333333  100.619792  177.585417  66.260417  54.337500
# wagon        -0.160000  102.156000  181.304000  66.256000  56.728000
# hardtop       1.875000   98.500000  176.937500  66.612500  52.850000
# convertible   2.833333   92.700000  170.383333  65.583333  51.433333
#
#              curb-weight  engine-size  compression-ratio   city-mpg  \
# body-style
# hatchback    2348.185714   114.400000           9.027429  26.314286
# sedan        2610.593750   130.822917          10.937500  25.322917
# wagon        2784.240000   123.840000          10.316000  24.040000
# hardtop      2810.625000   176.250000          10.725000  21.625000
# convertible  2801.666667   157.166667           8.933333  20.500000
#
#              highway-mpg
# body-style
# hatchback      32.171429
# sedan          30.833333
# ...

# %%
o.index
# Out:
# Index(['hatchback', 'sedan', 'wagon', 'hardtop', 'convertible'], dtype='object', name='body-style')

# %%
plt.figure(figsize=(9,6))
sns.barplot(auto['body-style'], auto['city-mpg'] , order=o.index)
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='city-mpg'>

# %%
plt.figure(figsize=(9,6))
sns.barplot(auto['city-mpg'],auto['body-style'])
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='city-mpg', ylabel='body-style'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(auto['body-style'])
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(auto['body-style'], order=auto['body-style'].value_counts().index)
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(auto['fuel-type'])
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fuel-type', ylabel='count'>

# %%
plt.figure(figsize=(10,7))
sns.set(rc={"axes.facecolor":"#283747", "axes.grid":False,'xtick.labelsize':14,'ytick.labelsize':14})
sns.countplot(auto['body-style'], order=auto['body-style'].value_counts(ascending = True).index)
# Out:
# c:\users\yashr\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
auto.corr()   
# corr()-> correlation -> It tells how variables in a dataset are related to each other and how they move concerning each other.
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.227691    -0.105790          -0.178515 -0.035823
# ...

# %%
sns.heatmap(auto.corr())
# Out:
# <AxesSubplot:>
